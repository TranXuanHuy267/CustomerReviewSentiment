# %%
import pandas as pd
data = pd.read_csv("../data/rawdata.csv")
data.drop(columns="Unnamed: 0", inplace=True)

# %%
data
# Out:
#                                        content  score  thumbsUpCount  \
# 0                  Rất thuận tiện, có lợi ích.      5              2
# 1                                          Tốt      4            213
# 2                                           Ok      5              1
# 3                    Xài rất tốt , nên tải nha      5              8
# 4                                       gútttt      5              1
# ...                                        ...    ...            ...
# 310741                                      Ok      5              0
# 310742                                 G o o d      5              0
# 310743                                      Có      5              0
# 310744         Nhiều lúc tôi k lấy đc hiệu ứng      1              0
# 310745  Tui chưa chơi ko biết có hay ko ??????      3              0
#
#        Application
# 0        Messenger
# 1        Messenger
# 2        Messenger
# 3        Messenger
# 4        Messenger
# ...            ...
# 310741   Instagram
# 310742   Instagram
# 310743   Instagram
# 310744   Instagram
# 310745   Instagram
#
# [310746 rows x 4 columns]

# %%
from datasets import load_dataset
dataset = load_dataset("uitnlp/vietnamese_students_feedback", cache_dir="../data")
dataset = dataset.rename_column("sentence", 'text')
dataset = dataset.rename_column("sentiment", 'label')
dataset = dataset.remove_columns("topic")
# Out:
# Using the latest cached version of the module from /Users/tranxuanhuy/.cache/huggingface/modules/datasets_modules/datasets/uitnlp--vietnamese_students_feedback/b01aa0fea00f1179ef9c093babb5e91f44bc60f19ded600754a08e018503e40f (last modified on Tue Dec 12 20:46:23 2023) since it couldn't be found locally at uitnlp/vietnamese_students_feedback., or remotely on the Hugging Face Hub.

# %%
i=101
dataset['train']['text'][25*i:25*(i+1)]
# Out:
# ['giảng viên dạy tốt .',
#  'kiến thức giảng hơi khó hiểu , nhưng giải bài tập hay hướng dẫn sinh viên làm bài thì dễ hiểu và còn tận tình chỉ bảo cho sinh viên những gì không biết , cô có thể nói lại , giảng lại một vấn đề vài lần nếu sinh viên vẫn chưa hiểu !',
#  'dạy đúng theo giáo trình .',
#  'mong giảng viên chủ động trong việc truyền đạt kiến thức hơn , tránh trường hợp đợi hỏi mới trả lời , vì sinh viên làm sao biết cái mình cần hỏi đề hỏi khi lực học mới chỉ ở mức trung bình .',
#  'cần giảng dạy kỹ phần trigger các từ cơ bản vì tìm kiếm trên mạng tương đối khó khăn dù chúng tương đương lập trình cơ bản .',
#  'thầy nhiệt tình , giảng kỹ , tận tâm với sinh viên .',
#  'giảng viên cần có kỹ năng sư phạm , truyền đạt nội dung môn học , thái độ nhiệt tình hơn .',
#  'sản phẩm mình làm ra , đem người khác báo cáo thì không được hợp lý .',
#  'thầy giảng hay , nhiệt tình .',
#  'giảng dạy dễ hiểu , nhiệt tình .',
#  'giảng viên tận tâm , nhiệt tình , phương pháp giảng dạy của giảng viên giúp hiểu được và vận dụng được kiến thức .',
#  'giảng viên giảng dạy nhiệt tình , bám sát chương trình .',
#  'dạy ít về phần code .',
#  'thầy không công bằng trong đánh giá .',
#  'giáo viên giảng dạy đầy đủ kiến thức , dễ tiếp thu , nhiệt tình giảng dạy .',
#  'thầy đi rất đúng giờ , giảng dạy rất nhiệt tình !',
#  'mà hơn nữa ngủ ở lớp học còn rất dễ bị đau lưng .',
#  'thầy rất hay liên hệ nhưng thứ học được ra thực tế , như những ứng dụng của các linh kiện , vdotv .',
#  'thầy thường vào lớp trễ .',
#  'thầy dạy dễ hiểu , hướng dẫn chi tiết .',
#  'giảng viên đến khá trễ .',
#  'thầy dạy phần hai có phần hơi khó khăn trong việc điểm danh , cả khi thầy có nhầm lẫn thầy cũng không chịu nhận .',
#  'giảng dạy còn nhiều thiết sót .',
#  'một môn học rất hay .',
#  'thầy tận tâm .']

# %%
import re
def cleaning(row):
    text = row['content'].strip()
    if isinstance(text, str): 
        text = text.lower()
        text = re.sub(r'[^ ,.?!a-z0-9àáảãạăắằẳẵặâấầẩẫậèéẻẽẹêếềểễệđìíỉĩịòóỏõọôốồổỗộơớờởỡợùúủũụưứừửữựỳýỷỹỵ]', '', text)
        text = re.sub(r'[.!?]+', '.', text)
        text = re.sub(r'([,.!?])\1+', r'\1', text)
        text = re.sub(r'[,]+', ' , ', text)
        text = re.sub(r'[.]+', ' . ', text)
        text = re.sub(r'([ ])\1+', r'\1', text)
        row['content'] = text.strip()
        return row
    return row

# %%
from copy import deepcopy

diction = {}
for i in range(len(data)):
    if data.loc[i, 'content'] not in diction.keys():
        diction[data.loc[i, 'content']] = [data.loc[i, 'score']]
    else:
        diction[data.loc[i, 'content']].append(data.loc[i, 'score'])
        diction[data.loc[i, 'content']] = list(set(diction[data.loc[i, 'content']]))

remained_reviews = list(set([i for i, j in diction.items() if len(j)<2]))
data_output = deepcopy(data)
data_output = data_output[data_output['content'].isin(remained_reviews)]
data_output = data_output.apply(cleaning, axis=1)

removed_reviews_2 = [
    'g7mb',
    'samsung galaxy s21 ultra 5 g smg988b',
    'd4e',
    'yhehe',
    'messengr',
    'heé34e',
    'ịckhylh',
    'đbb',
    'chetme',
    'hhhhhhhhokkkk',
    'đjtme',
    'cmn',
    'như l',
    'meslon',
    'vcl',
    'cc',
    'dm',
    ' . ',
    'cl',
    'như c',
    'del',
    'đb',
    'dcm',
    'explore',
    'loz',
    'hi hi',
    'cưk',
    'meomeo',
    'vkl', 
    'ghi chú',
    'nhon nhặc',
    'vl',
    'lon',
    'lol',
    'đm',
    'haha',
    'đitme',
    'cặc',
    'thoănh',
    'anơnh',
    'moẹ',
    'cm',
    'mày',
    'tao',
    'gg',
    'sl',
    'éo',
    'gjhbhv',
    'hihi',
    'lll',
    'mẹ',
    'xz',
    'toots',
    'ckg',
    'bgi',
    '7e',
    'b b',
    'xxx',
    'srtxatjrx',
    '. 0',
    'di 0',
    'hô hô',
    'èy',
    'el .',
    'đe 3e',
    'eq',
    'qê',
    'êư',
    'lm',
    'za',
    'gồ',
    'bạnbạn',
    'snisb',
    'ld',
    'hehe',
    '4gu',
    'u9',
    'h0',
    'kwwiwieie',
    'kw',
    'wiw',
    'wie',
    'iei',
    'eie',
    'ioo',
    'yyy',
    'ê3',
    'i c',
    'ẻcv',
    'mọe',
    'đel',
    'bòi',
    'wp',
    'medi',
    'boài',
    'gf',
    'amv',
    'am1',
    'hah',
    'ean',
    'cec',
    'bìu',
    'ut',
    '7j',
    'qq',
    'đức',
    'l0',
    '2 .',
    'ab',
    'bcd',
    'zx',
    'iz',
    'aa của',
    'kui',
    'vsn',
    'djt',
    'buoi',
    'đeoz',
    'cặt',
    'jav',
    'l y',
    'dsha',
    'dj',
    'rw',
    'cuc',
    'cẹc',
    'dahezwre',
    'đíu',
    'như nhái nhồn',
    'hd',
    'căc',
    'xuyn',
    'hya',
    'ỳy',
    'đ8',
    'duk',
    'ukis',
    'kisko',
    'skor',
    'oop',
    'akd',
    'kden',
    'eod',
    'zef',
    'osk',
    'kajs',
    'như .',
    'đ ',
    'dfd',
    '2v',
    'gyg',
    'kkkkkk',
]
for substring in removed_reviews_2:
    data_output = data_output[~data_output['content'].str.contains(substring)]
    
data_output = data_output[~data_output['content'].isin(['', '.', ',', 'c'])]
data_output = data_output[~data_output['content'].str.startswith(".")]

data_output.reset_index(inplace=True)
data_output.drop(columns='index', inplace=True)
data_output
# Out:
#                                                   content  score  \
# 0                                                  gútttt      5
# 1                                          không làm được      1
# 2                         đăng xuất ra vô lại bị lỗi nhìu      1
# 3                             app nt nhưng nhắn ko ai trl      1
# 4                                   cập nhật lại giùm cái      5
# ...                                                   ...    ...
# 119792  chụp đẹp nhưng chưa có tính năng giây nha mong...      4
# 119793                                  điện video bị lỗi      1
# 119794                                             ok nhé      5
# 119795                  chụp ảnh lưu về máy xem lại ko có      1
# 119796                                             ap hay      5
#
#         thumbsUpCount Application
# 0                   1   Messenger
# 1                   1   Messenger
# 2                   1   Messenger
# 3                  48   Messenger
# 4                   2   Messenger
# ...               ...         ...
# 119792              0   Instagram
# 119793              0   Instagram
# 119794              0   Instagram
# 119795              0   Instagram
# 119796              0   Instagram
#
# [119797 rows x 4 columns]

# %%
i = 1792
data_output['content'].tolist()[20*i:20*(i+1)]
# Out:
# ['thoát ra là hk vào đc',
#  'tuệt vời',
#  'gì mà tin nhắn không nhận được z',
#  '1 sao mặc định',
#  'hay lắm iu iu',
#  'tật tởm',
#  'mở ko dc',
#  'mở không được mess',
#  'mess dạo này ko đáng dùng nữa',
#  'it failed worse than it made me really hope',
#  'làm ơn cho gửi file qua mess',
#  'tự dưng cập nhật xong ko vào đc mess nữa mong nhà phát hành điều chỉnh ạ',
#  'message sao bị lỗi hoài không gửi được tin nhắn',
#  'thường xuyên không vào được .',
#  'rât tiên lơi ưng dung nay cac ban tai vê dung',
#  't call sài filter kh đc 1',
#  'quá chán vs bản này .',
#  'cập nhật hoài z',
#  'cải thiện thêm đi',
#  'gọi lag muốn chet']

# %%
i = 10
data_output['score'].tolist()[208]
# Out:
# 3

# %%
x = ". "
x in "hello ."
# Out:
# False
