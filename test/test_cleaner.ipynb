# %% [markdown]
# ## Config

# %%
# %cd ..
# Out:
# /Users/tranxuanhuy/Documents/20231+20232/Sentiment Analysis

# %%
# assure "data" folder in the output list
# !ls
# Out:
# data  test  utils

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Cleaning

# %%
import pandas as pd
from utils.cleaner import cleaning

# %%
data = pd.read_csv('data/rawdata.csv')
data['content'] = data['content'].apply(cleaning)
data
# Out:
#         Unnamed: 0                             content  score  thumbsUpCount  \
# 0                0      rất thuận tiện , có lợi ích .       5              2
# 1                1                                 tốt      4            213
# 2                2                                  ok      5              1
# 3                3           xài rất tốt , nên tải nha      5              8
# 4                4                              gútttt      5              1
# ...            ...                                 ...    ...            ...
# 310741       99995                                  ok      5              0
# 310742       99996                             g o o d      5              0
# 310743       99997                                  có      5              0
# 310744       99998     nhiều lúc tôi k lấy đc hiệu ứng      1              0
# 310745       99999  tui chưa chơi ko biết có hay ko .       3              0
#
#        Application
# 0        Messenger
# 1        Messenger
# 2        Messenger
# 3        Messenger
# 4        Messenger
# ...            ...
# 310741   Instagram
# 310742   Instagram
# 310743   Instagram
# 310744   Instagram
# 310745   Instagram
#
# [310746 rows x 5 columns]

# %% [markdown]
# ## Manual Test

# %%
raw_data = pd.read_csv('data/rawdata.csv')

i = 1
for i in range(9*i, 9*(i+1)):
    print(raw_data.loc[i, 'content'])
    print(data.loc[i, 'content'])
    print()
# Out:
# Áp lỏ vô cũng không cô được, đúng chịu
# áp lỏ vô cũng không cô được , đúng chịu
#
# Ghi chú đâu:)?
# ghi chú đâu .
#
# như cc
# như cc
#
# K có ghi chú
# k có ghi chú
#
# Không có ghi chú
# không có ghi chú
#
# rất hài lòng
# rất hài lòng
#
# Mong có ghi chú
# mong có ghi chú
#
# như l, không cho gọi ngiu 1 sao là quá nhìu
# như l , không cho gọi ngiu 1 sao là quá nhìu
#
# Tin nhắn về k báo luôn
# tin nhắn về k báo luôn
